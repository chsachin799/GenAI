# %%
from langgraph.graph import StateGraph,START,END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model='gemini-flash-latest')

# %%
class BlogState(TypedDict):
    title:str
    outline:str
    content:str

# %%
def create_outline(state:BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f"Generate an outline for a blog on the topic {title}"
    outline = model.invoke(prompt).text

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state:BlogState) -> BlogState:

    # fetch title and outline
    title = state['title']
    outline = state['outline']

    # call llm gen outline
    prompt = f"Write a detailed blog on the title - {title} using the following outline \n {outline}"
    content = model.invoke(prompt).text

    # update state
    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)

# edges
graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

# compile
workflow = graph.compile()

# %%
initial_state = {'title':'Rise of AI in Nepal'}
final_state=workflow.invoke(initial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in Nepal', 'outline': 'Here is a comprehensive blog post outline on **"The Rise of AI in Nepal: Opportunities, Innovations, and Challenges."** \n\n---\n\n### **Catchy Title Ideas:**\n1. From Himalayas to Algorithms: The Rise of AI in Nepal\n2. The AI Revolution in Nepal: How Technology is Shaping the Land of Everest\n3. Nepal’s AI Awakening: Opportunities, Current Trends, and the Road Ahead\n\n---\n\n### **I. Introduction**\n*   **The Hook:** Mention the global AI wave (ChatGPT, automation) and pivot to how this wave is hitting Nepal.\n*   **Context:** Brief overview of Nepal’s transition from a traditionally agriculture-based economy to a growing tech hub.\n*   **Thesis Statement:** AI is no longer a futuristic concept in Nepal; it is actively transforming education, local businesses, and public services, while presenting unique challenges and immense opportunities.\n\n---\n\n### **II. The Current AI Landscape in Nepal**\n*   **Academic Initiatives & Education:**\n    *   Introduction of Data Science and AI degrees in universities (e.g., Kathmandu University, Tribhuvan University).\n    *   Role of global/local fellowships (e.g., Fusemachines AI Fellowships).\n*   **Growth of Tech Companies and Startups:**\n    *   Shift from basic software outsourcing to AI, Machine Learning, and Data Analytics solutions.\n    *   Local startups integrating AI into everyday services (chatbots, recommendation systems).\n*   **Grassroots & Community Efforts:**\n    *   Tech communities, hackathons, and AI meetups fostering local talent.\n\n---\n\n### **III. Key Sectors Being Transformed by AI in Nepal**\n1.  **Healthcare:**\n    *   AI in tele-medicine to bridge the urban-rural healthcare gap.\n    *   AI-powered diagnostics (e.g., analyzing X-rays or skin conditions in remote areas).\n2.  **Agriculture:**\n    *   Predictive modeling for weather patterns and crop yields.\n    *   AI tools for pest detection using smartphone cameras.\n3.  **Language and Natural Language Processing (NLP):**\n    *   Development of AI models for Nepali and local languages (Nepali NLP, text-to-speech, speech-to-text).\n    *   Preserving indigenous languages through digital archiving and machine learning.\n4.  **Finance and Fintech:**\n    *   AI-driven fraud detection in digital wallets (e.g., eSewa, Khalti).\n    *   Automated credit scoring and customer service bots in banking.\n5.  **Tourism and Hospitality:**\n    *   AI personalized travel itineraries for international tourists.\n\n---\n\n### **IV. Challenges Facing Nepal’s AI Growth**\n*   **Brain Drain:** The exodus of skilled IT talent to foreign countries for better opportunities.\n*   **Infrastructure Deficits:** Unreliable high-speed internet in remote regions and high costs of computing infrastructure (GPUs/cloud storage).\n*   **Data Scarcity:** Lack of localized, digitized data to train accurate AI models.\n*   **Lack of Government Policy & Regulation:** Absence of clear guidelines regarding AI ethics, data privacy, and intellectual property.\n\n---\n\n### **V. The Road Ahead: How Nepal Can Capitalize on the AI Boom**\n*   **Government Role:** Implementing the *Digital Nepal Framework* with a strong emphasis on AI research and infrastructure.\n*   **Public-Private Partnerships:** Encouraging collaboration between local tech firms, academia, and foreign investors.\n*   **Niche Positioning:** Positioning Nepal as a cost-effective, high-quality hub for global AI outsourcing and research.\n\n---\n\n### **VI. Conclusion**\n*   **Summary:** Recount the key points—Nepal is at a crucial crossroads where embracing AI can accelerate economic growth.\n*   **Final Thought:** AI shouldn\'t just be imported to Nepal; Nepal can build AI solutions tailored to its unique geography and cultural context.\n*   **Call to Action (CTA):** Ask readers: *"How do you think AI will impact your field in Nepal? Leave a comment below!"* or invite them to share the post.\n\n---\n\n### **Tips for Writing the ...

# %%
print(final_state['title'])
# Out:
# Rise of AI in Nepal

# %%
print(final_state['outline'])
# Out:
# Here is a comprehensive blog post outline on **"The Rise of AI in Nepal: Opportunities, Innovations, and Challenges."**
#
# ---
#
# ### **Catchy Title Ideas:**
# 1. From Himalayas to Algorithms: The Rise of AI in Nepal
# 2. The AI Revolution in Nepal: How Technology is Shaping the Land of Everest
# 3. Nepal’s AI Awakening: Opportunities, Current Trends, and the Road Ahead
#
# ---
#
# ### **I. Introduction**
# *   **The Hook:** Mention the global AI wave (ChatGPT, automation) and pivot to how this wave is hitting Nepal.
# *   **Context:** Brief overview of Nepal’s transition from a traditionally agriculture-based economy to a growing tech hub.
# *   **Thesis Statement:** AI is no longer a futuristic concept in Nepal; it is actively transforming education, local businesses, and public services, while presenting unique challenges and immense opportunities.
#
# ---
#
# ### **II. The Current AI Landscape in Nepal**
# *   **Academic Initiatives & Education:**
#     *   Introduction of Data Science and AI degrees in universities (e.g., Kathmandu University, Tribhuvan University).
#     *   Role of global/local fellowships (e.g., Fusemachines AI Fellowships).
# *   **Growth of Tech Companies and Startups:**
#     *   Shift from basic software outsourcing to AI, Machine Learning, and Data Analytics solutions.
#     *   Local startups integrating AI into everyday services (chatbots, recommendation systems).
# *   **Grassroots & Community Efforts:**
#     *   Tech communities, hackathons, and AI meetups fostering local talent.
#
# ---
#
# ### **III. Key Sectors Being Transformed by AI in Nepal**
# 1.  **Healthcare:**
#     *   AI in tele-medicine to bridge the urban-rural healthcare gap.
#     *   AI-powered diagnostics (e.g., analyzing X-rays or skin conditions in remote areas).
# 2.  **Agriculture:**
#     *   Predictive modeling for weather patterns and crop yields.
#     *   AI tools for pest detection using smartphone cameras.
# 3.  **Language and Natural Language Processing (NLP):**
#     *   Development of AI models for Nepali and local languages (Nepali NLP, text-to-speech, speech-to-text).
#     *   Preserving indigenous languages through digital archiving and machine learning.
# 4.  **Finance and Fintech:**
#     *   AI-driven fraud detection in digital wallets (e.g., eSewa, Khalti).
#     *   Automated credit scoring and customer service bots in banking.
# 5.  **Tourism and Hospitality:**
#     *   AI personalized travel itineraries for international tourists.
#
# ---
#
# ### **IV. Challenges Facing Nepal’s AI Growth**
# *   **Brain Drain:** The exodus of skilled IT talent to foreign countries for better opportunities.
# *   **Infrastructure Deficits:** Unreliable high-speed internet in remote regions and high costs of computing infrastructure (GPUs/cloud storage).
# *   **Data Scarcity:** Lack of localized, digitized data to train accurate AI models.
# *   **Lack of Government Policy & Regulation:** Absence of clear guidelines regarding AI ethics, data privacy, and intellectual property.
#
# ---
#
# ### **V. The Road Ahead: How Nepal Can Capitalize on the AI Boom**
# *   **Government Role:** Implementing the *Digital Nepal Framework* with a strong emphasis on AI research and infrastructure.
# *   **Public-Private Partnerships:** Encouraging collaboration between local tech firms, academia, and foreign investors.
# *   **Niche Positioning:** Positioning Nepal as a cost-effective, high-quality hub for global AI outsourcing and research.
#
# ---
#
# ### **VI. Conclusion**
# *   **Summary:** Recount the key points—Nepal is at a crucial crossroads where embracing AI can accelerate economic growth.
# *   **Final Thought:** AI shouldn't just be imported to Nepal; Nepal can build AI solutions tailored to its unique geography and cultural context.
# *   **Call to Action (CTA):** Ask readers: *"How do you think AI will impact your field in Nepal? Leave a comment below!"* or invite them to share the post.
#
# ---
#
# ### **Tips for Writing the Post:**
# *   **Include Real Examples:** Mention real Nepalese companies, organizations, or open-source projects working on AI (e.g., Fusemachines, Paaila Technology, local university research groups).
# *   **Use Visuals:** Include infographics about tech stats in Nepal, photos of local tech events, or graphics representing AI in rural settings.
# *   **Keep it Accessible:** Balance technical terms with plain language so non-tech readers can understand the impact.

# %%
print(final_state['content'])
# Out:
# # From Himalayas to Algorithms: The Rise of AI in Nepal
#
# When people think of Nepal, imagery of snow-capped peaks, ancient temples, and serene trekking trails usually comes to mind. Yet, beneath the shadow of Mt. Everest, a quiet revolution is taking root—one driven by neural networks, predictive algorithms, and lines of code.
#
# Across the globe, artificial intelligence (AI) is redefining human capability, propelled by breakthrough tools like ChatGPT, Midjourney, and automated enterprise workflows. Far from being a passive spectator, Nepal is beginning to ride this technological wave.
#
# As the country navigates a long-term transition from a traditionally agriculture-dominated economy to a tech-enabled nation, artificial intelligence is proving to be a game-changer. AI is no longer a futuristic concept reserved for Silicon Valley; it is actively transforming classrooms, local enterprises, and public services across Nepal. However, unlocking its full potential requires navigating critical hurdles along the way.
#
# ---
#
# ## The Current AI Landscape in Nepal
#
# The foundation of Nepal’s emerging AI ecosystem rests on three core pillars: higher education, forward-thinking tech enterprises, and grass-roots developer communities.
#
# ```
#                   ┌──────────────────────────────┐
#                   │   Nepal's AI Ecosystem       │
#                   └──────────────┬───────────────┘
#                                  │
#          ┌───────────────────────┼───────────────────────┐
#          ▼                       ▼                       ▼
# ┌─────────────────┐     ┌─────────────────┐     ┌─────────────────┐
# │ Academic Progress│     │ Local Startups  │     │ Community Drive │
# │  (KU, TU, AI    │     │  (Fusemachines, │     │  (Hackathons,   │
# │   Fellowships)  │     │   Paaila Tech)  │     │   Open-Source)  │
# └─────────────────┘     └─────────────────┘     └─────────────────┘
# ```
#
# ### 1. Academic Initiatives & Education
# Higher education in Nepal is adapting to global technological shifts. Leading institutions like **Kathmandu University (KU)** and **Tribhuvan University (TU)** have introduced specialized coursework in Data Science, Machine Learning, and Computer Science with AI tracks.
#
# Simultaneously, private enterprise is stepping in to bridge the skill gap. Companies like **Fusemachines** have spearheaded AI education through initiatives like the *Fusemachines AI Fellowship*. This program has equipped hundreds of Nepali students and engineers with industry-level skills in deep learning, natural language processing (NLP), and computer vision.
#
# ### 2. Growth of Tech Companies and Startups
# Nepal’s IT sector was once dominated by basic software development and web-design outsourcing. Today, local firms are pivoting toward high-value services involving data analytics, predictive modeling, and intelligent automation.
#
# Prominent startups and firms are making waves:
# * **Fusemachines Nepal:** A key catalyst in creating an AI-ready talent pool and providing enterprise-grade AI solutions globally.
# * **Paaila Technology:** Known for developing service-oriented robotics and AI solutions, such as *Pari*, a customer-service robot deployed in local banks.
# * **Local Agencies:** Dev shops across Kathmandu, Lalitpur, and Pokhara are increasingly integrating conversational AI and automated workflows into foreign and domestic client applications.
#
# ### 3. Grassroots & Community Efforts
# Community-driven platforms—including local data science clubs, developer meetups, and open-source initiatives—are cultivating local talent. Student-led hackathons frequently center around local problem-solving, encouraging young engineers to apply machine learning to real-world Nepali issues.
#
# ---
#
# ## Key Sectors Being Transformed by AI in Nepal
#
# AI isn't just elevating the IT industry—it is extending into sectors vital to everyday Nepali life.
#
# ```
# +-------------------------------------------------------------------+
# |               SECTORS BEING TRANSFORMED BY AI                     |
# +------------------+------------------+-----------------------------+
# | Healthcare       | Diagnostics      | Tele-medicine screening     |
# | Agriculture      | Disease control  | Crop yield predictions      |
# | NLP & Language   | Digitization     | Nepali NLP & TTS tools      |
# | Fintech          | Security         | AI fraud detection          |
# | Tourism          | Personalization  | Smart travel itineraries    |
# +------------------+------------------+-----------------------------+
# ```
#
# ### 1. Healthcare
# Bridging the divide between urban medical hubs and under-resourced rural healthcare centers remains a persistent challenge in Nepal.
#
# AI-powered diagnostic tools are helping close this gap. Lightweight, computer-vision models can analyze X-rays to screen for conditions like Tuberculosis—a major public health concern—in remote health posts without requiring an on-site radiologist. Furthermore, AI-enhanced telemedicine platforms help rural health workers triage patients and connect them with specialists in Kathmandu.
#
# ### 2. Agriculture
# Agriculture contributes significantly to Nepal's GDP and employs a vast portion of its workforce. Smart farming tools are beginning to modernise traditional practices:
# * **Pest & Disease Detection:** Farmers can capture photos of diseased crops using a smartphone, allowing mobile AI models to diagnose issues and recommend localized treatments.
# * **Predictive Weather & Yield Modeling:** Machine learning models process satellite imagery and weather data to help farmers decide optimal planting and harvesting schedules.
#
# ### 3. Language and Natural Language Processing (NLP)
# For AI to truly serve Nepal, it must speak Nepali and local languages. Developing robust **Nepali Natural Language Processing (NLP)** models is essential.
#
# Local researchers and open-source contributors are building dataset pipelines for:
# * Speech-to-text and text-to-speech engine development in Nepali.
# * Fine-tuning Open LLMs (Large Language Models) to accurately process Nepali script and context.
# * Digital archiving and preservation of endangered indigenous languages, such as Nepal Bhasa, Maithili, and Tamang.
#
# ### 4. Finance and Fintech
# Digital payment adoption in Nepal has accelerated thanks to digital wallets like **eSewa**, **Khalti**, and **Fonepay**.
#
# ```
# [ User Transaction ] ──> [ Digital Wallet Platform ] ──> [ Real-time AI Anomaly Engine ] ──> [ Approved / Flagged ]
# ```
#
# As digital transactions surge, financial institutions use machine learning for **real-time fraud detection**, analyzing transaction anomalies instantaneously. Additionally, conversational chatbots handle routine customer queries, while automated credit scoring tools evaluate loan eligibility for underserved populations.
#
# ### 5. Tourism and Hospitality
# Tourism is a cornerstone of Nepal's economy. AI tools are modernizing how travel experiences are built.
# From personalized itinerary planners tailored to trekking preferences to real-time AI translators assisting foreign travelers, smart automation is streamlining travel logistics, helping tourists explore Nepal safely and efficiently.
#
# ---
#
# ## Challenges Facing Nepal’s AI Growth
#
# While the potential is clear, several structural hurdles limit rapid scaling.
#
# > *"Technology can solve problems, but infrastructure and human capital sustain the solution."*
#
# ```
#                      ┌─────────────────────────────┐
#                      │   NEPAL'S AI CHALLENGES     │
#                      └──────────────┬──────────────┘
#                                     │
#        ┌──────────────────┬─────────┴────────┬──────────────────┐
#        ▼                  ▼                  ▼                  ▼
# ┌──────────────┐   ┌──────────────┐   ┌──────────────┐   ┌──────────────┐
# │ Brain Drain  │   │ Infrastructure│  │ Data Scarcity│   │ Missing Policy│
# │ High-talent  │   │ High GPU cost │  │ Unstructured │   │ Lack of standard│
# │ migration    │   │ Rural connectivity│ localized data │ regulatory frameworks│
# └──────────────┘   └──────────────┘   └──────────────┘   └──────────────┘
# ```
#
# 1. **Brain Drain:** Skilled software engineers, data scientists, and AI researchers often emigrate to foreign markets (such as the US, Australia, and Europe) offering better compensation, advanced research infrastructure, and higher standards of living.
# 2. **Infrastructure Deficits:** Training modern AI models requires powerful hardware (GPUs) and dependable high-speed internet. Outside major urban centers like Kathmandu and Pokhara, connectivity can be unpredictable, and high computing hardware costs remain prohibitive for early-stage startups.
# 3. **Data Scarcity:** AI models thrive on quality data. Much of Nepal's historical health, agricultural, and administrative records remain non-digitized or unstructured, creating a "data bottleneck" for building localized solutions.
# 4. **Lack of Government Policy & Regulation:** Nepal lacks a comprehensive national AI strategy. Policies regarding data privacy, intellectual property rights, AI ethics, and automated decision-making are still in their infancy, leading to uncertainty for enterprise investors.
#
# ---
#
# ## The Road Ahead: How Nepal Can Capitalize on the AI Boom
#
# To convert early momentum into sustainable growth, concerted efforts are required across sectors:
#
# ```
#                           Strategic Roadmap
#
# ┌──────────────────┐     ┌──────────────────┐     ┌──────────────────┐
# │   GOVERNMENT     │     │ PUBLIC-PRIVATE   │     │    GLOBAL        │
# │   POLICY         │ ──> │ PARTNERSHIPS     │ ──> │    POSITIONING   │
# │ Actively implement│     │ Academic-Industry│     │ High-value tech  │
# │ Digital Nepal    │     │ feedback loops   │     │ export hub       │
# └──────────────────┘     └──────────────────┘     └──────────────────┘
# ```
#
# * **Targeted Government Strategy:** The government should expand the scope of its **Digital Nepal Framework** to include focused AI research funding, localized open-data repositories, and tax incentives for tech startups.
# * **Public-Private Partnerships:** Universities must partner directly with domestic tech companies to align curricula with market needs, fund research labs, and incentivize high-value remote work opportunities so local talent stays in the country.
# * **Strategic Global Positioning:** Instead of trying to build generalized foundational models from scratch, Nepal can specialize in specialized domains: high-efficiency lower-cost model fine-tuning, complex data annotation, localized NLP services, and niche software applications.
#
# ---
#
# ## Conclusion
#
# Nepal stands at a digital crossroads. The integration of artificial intelligence is no longer just about adopting global trends—it is about deploying innovative tools to solve localized challenges, from mountain geography barriers to health and educational access.
#
# By addressing critical challenges like brain drain, data availability, and infrastructure, Nepal can transition from being an importer of technology to an active innovator in regional AI deployment.
#
# ***
#
# ### What Do You Think?
# How do you foresee AI shaping your field or daily life in Nepal over the coming decade? Will it bridge economic gaps or create new challenges?
#
# **Share your thoughts in the comments below, and pass this post along to keep the conversation going!**
